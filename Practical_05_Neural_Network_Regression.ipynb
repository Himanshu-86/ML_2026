# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu-86/ML_2026/blob/main/Practical_05_Neural_Network_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practical 05: Neural Network Regression (Boston Housing)
#
# ## Dataset: Boston Housing Dataset
# ## Subject: Machine Learning
#
# Objective: Predict house prices using a Neural Network model.

# %% [markdown]
# ## Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# ## Load Dataset

# %%
data = pd.read_csv("BostonHousing.csv")
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# ## Feature and Target Split

# %%
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

# %% [markdown]
# ## Feature Scaling

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# ## Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# %% [markdown]
# ## Build Neural Network Model

# %%
model = Sequential()

model.add(Dense(50, activation='relu', input_dim=13))
model.add(Dense(50, activation='relu'))
model.add(Dense(30, activation='relu'))
model.add(Dense(1))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## Compile Model

# %%
model.compile(
    optimizer='adam',
    loss='mean_squared_error',
    metrics=['mae']
)

# %% [markdown]
# ## Train Model

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 628.8550 - mae: 23.0978 - val_loss: 556.8937 - val_mae: 22.0543
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 589.0919 - mae: 22.2260 - val_loss: 519.0987 - val_mae: 21.1902
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 542.6621 - mae: 21.1608 - val_loss: 466.9041 - val_mae: 19.9581
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 476.2548 - mae: 19.5700 - val_loss: 393.2049 - val_mae: 18.0944
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 384.9758 - mae: 17.2059 - val_loss: 291.1757 - val_mae: 15.2947
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 267.9211 - mae: 13.8377 - val_loss: 173.6927 - val_mae: 11.3238
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 150.7515 - mae: 9.8429 - val_loss: 80.1596 - val_mae: 6.9644
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 81.5547 - mae: 7.2396 - val_loss: 51.0601 - val_mae: 5.3376
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 67.9447 - mae: 6.5549 - val_loss: 42.7832 - val_mae: 4.8948
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 50.5088 - mae: 5.5791 - val_loss: 35.9039 - val_mae: 4.3904
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 38.9143 - mae: 4.7840 - val_loss: 32.8132 - val_mae: 4.1760
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 31.4732 - mae: 4.2503 - val_loss: 29.2681 - val_mae: 3.8802
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 26.7463 - mae: 3.8688 - val_loss: 27.9435 - val_mae: 3.7993
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 23.7357 - mae: 3.6098 - val_loss: 26.6602 - val_mae: 3.7282
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 21.7524 - mae: 3.4379 - val_loss: 26.3989 - val_mae: 3.6378
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 20.1139 - mae: 3.2668 - val_loss: 26.5406 - val_mae: 3.6369
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 19.1061 - mae: 3.1769 - val_loss: 25.6146 - val_mae: 3.5359
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 18.0740 - mae: 3.0926 - val_loss: 25.0322 - val_mae: 3.4822
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 17.4307 - mae: 3.0300 - val_loss: 24.1811 - val_mae: 3.3847
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 16.7942 - mae: 2.9609 - val_loss: 23.5329 - val_mae: 3.3131
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 16.3158 - mae: 2.9188 - val_loss: 23.3054 - val_mae: 3.2712
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 15.8500 - mae: 2.8618 - val_loss: 22.8976 - val_mae: 3.2320
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 15.1440 - mae: 2.8138 - val_loss: 22.3972 - val_mae: 3.2471
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 14.9809 - mae: 2.7787 - val_loss: 21.7014 - val_mae: 3.1423
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 14.4525 - mae: 2.7270 - val_loss: 21.4403 - val_mae: 3.1319
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 14.1476 - mae: 2.7024 - val_loss: 21.2345 - val_mae: 3.1097
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13.8938 - mae: 2.6792 - val_loss: 20.9359 - val_mae: 3.0881
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13.5686 - mae: 2.6291 - val_loss: 21.1397 - val_mae: 3.0587
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13.2868 - mae: 2.6088 - val_loss: 20.4844 - val_mae: 3.0445
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13.0381 - mae: 2.5998 - val_loss: 19.9004 - val_mae: 3.0320
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 12.9204 - mae: 2.5773 - val_loss: 19.5106 - val_mae: 2.9472
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 12.6418 - mae: 2.5611 - val_loss: 19.8712 - val_mae: 2.9953
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 12.4271 - mae: 2.5511 - val_loss: 19.5252 - val_mae: 2.9688
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 12.2106 - mae: 2.5289 - val_loss: 19.3987 - val_mae: 2.9466
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 12.0412 - mae: 2.5134 - val_loss: 19.0652 - val_mae: 2.9191
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 11.8905 - mae: 2.4944 - val_loss: 18.7344 - val_mae: 2.9213
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 11.7893 - mae: 2.4962 - val_loss: 18.9358 - val_mae: 2.8646
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.7770 - mae: 2.4894 - val_loss: 18.9192 - val_mae: 2.9440
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.5818 - mae: 2.4656 - val_loss: 18.2317 - val_mae: 2.8154
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 11.2006 - mae: 2.4344 - val_loss: 18.8173 - val_mae: 2.9127
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 11.0443 - mae: 2.4204 - val_loss: 18.3617 - val_mae: 2.8562
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 10.8811 - mae: 2.4048 - val_loss: 18.2631 - val_mae: 2.8381
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 10.9054 - mae: 2.4087 - val_loss: 18.0785 - val_mae: 2.8869
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 10.6366 - mae: 2.3790 - val_loss: 17.4090 - val_mae: 2.7734
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 10.6864 - mae: 2.3710 - val_loss: 17.9153 - val_mae: 2.8494
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 10.4581 - mae: 2.3515 - val_loss: 17.4295 - val_mae: 2.8219
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 10.2404 - mae: 2.3307 - val_loss: 17.2470 - val_mae: 2.7671
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 10.1490 - mae: 2.3369 - val_loss: 17.6844 - val_mae: 2.8525
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.9650 - mae: 2.3155 - val_loss: 16.8922 - val_mae: 2.7636
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.8704 - mae: 2.2954 - val_loss: 17.2759 - val_mae: 2.7863
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.7674 - mae: 2.2973 - val_loss: 17.4709 - val_mae: 2.8386
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.6835 - mae: 2.2913 - val_loss: 17.3782 - val_mae: 2.8361
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.5701 - mae: 2.2715 - val_loss: 16.7969 - val_mae: 2.7653
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.4648 - mae: 2.2534 - val_loss: 16.7115 - val_mae: 2.8125
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.4350 - mae: 2.2436 - val_loss: 16.8238 - val_mae: 2.7638
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.2459 - mae: 2.2409 - val_loss: 16.6509 - val_mae: 2.8092
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.0751 - mae: 2.2145 - val_loss: 16.2847 - val_mae: 2.7545
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.0020 - mae: 2.2045 - val_loss: 16.2111 - val_mae: 2.7439
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.9440 - mae: 2.2021 - val_loss: 16.4255 - val_mae: 2.7813
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.8724 - mae: 2.1898 - val_loss: 16.4367 - val_mae: 2.7535
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.6889 - mae: 2.1646 - val_loss: 16.0740 - val_mae: 2.7949
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.6448 - mae: 2.1720 - val_loss: 15.9052 - val_mae: 2.7331
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.4922 - mae: 2.1556 - val_loss: 16.3591 - val_mae: 2.8055
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.4708 - mae: 2.1467 - val_loss: 16.1495 - val_mae: 2.7567
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.3978 - mae: 2.1295 - val_loss: 15.5988 - val_mae: 2.7490
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.2993 - mae: 2.1281 - val_loss: 15.7231 - val_mae: 2.7694
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.1976 - mae: 2.1227 - val_loss: 15.5467 - val_mae: 2.7165
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.0464 - mae: 2.1035 - val_loss: 15.7828 - val_mae: 2.7760
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.0402 - mae: 2.1040 - val_loss: 15.5070 - val_mae: 2.7535
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.9164 - mae: 2.0917 - val_loss: 15.4331 - val_mae: 2.7314
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.8111 - mae: 2.0802 - val_loss: 15.2052 - val_mae: 2.7472
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.7634 - mae: 2.0628 - val_loss: 15.3605 - val_mae: 2.7362
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.7097 - mae: 2.0551 - val_loss: 15.5445 - val_mae: 2.7745
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.5588 - mae: 2.0453 - val_loss: 14.9965 - val_mae: 2.6960
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.7123 - mae: 2.0524 - val_loss: 14.7985 - val_mae: 2.7318
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.6003 - mae: 2.0624 - val_loss: 15.0393 - val_mae: 2.6734
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.4989 - mae: 2.0355 - val_loss: 15.3868 - val_mae: 2.7810
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.2250 - mae: 2.0077 - val_loss: 14.6266 - val_mae: 2.6626
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.1740 - mae: 2.0002 - val_loss: 14.6794 - val_mae: 2.7032
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.0702 - mae: 1.9886 - val_loss: 14.3982 - val_mae: 2.6897
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.0207 - mae: 1.9782 - val_loss: 14.6948 - val_mae: 2.7289
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.9118 - mae: 1.9692 - val_loss: 14.5583 - val_mae: 2.7191
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.8447 - mae: 1.9637 - val_loss: 14.3464 - val_mae: 2.6920
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.8143 - mae: 1.9689 - val_loss: 14.0366 - val_mae: 2.6681
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.7148 - mae: 1.9454 - val_loss: 14.2329 - val_mae: 2.6953
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.6424 - mae: 1.9329 - val_loss: 14.5449 - val_mae: 2.7432
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.7315 - mae: 1.9507 - val_loss: 14.3411 - val_mae: 2.7047
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.5920 - mae: 1.9310 - val_loss: 14.0697 - val_mae: 2.6973
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.5580 - mae: 1.9248 - val_loss: 13.9025 - val_mae: 2.6841
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.4211 - mae: 1.9087 - val_loss: 13.9038 - val_mae: 2.6978
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2667 - mae: 1.8980 - val_loss: 13.7347 - val_mae: 2.6703
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2273 - mae: 1.8827 - val_loss: 14.1599 - val_mae: 2.7299
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.3805 - mae: 1.9052 - val_loss: 13.9824 - val_mae: 2.6939
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.0419 - mae: 1.8611 - val_loss: 13.6056 - val_mae: 2.6783
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.0082 - mae: 1.8536 - val_loss: 13.5777 - val_mae: 2.6715
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.9308 - mae: 1.8429 - val_loss: 13.7967 - val_mae: 2.6885
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.9446 - mae: 1.8446 - val_loss: 13.7705 - val_mae: 2.6831
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.9598 - mae: 1.8628 - val_loss: 13.7244 - val_mae: 2.6804
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.9933 - mae: 1.8381 - val_loss: 13.9859 - val_mae: 2.7176
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6493 - mae: 1.8107 - val_loss: 13.4260 - val_mae: 2.6526

# %% [markdown]
# ## Model Evaluation

# %%
loss, mae = model.evaluate(X_test, y_test)

print("Test Loss:", loss)
print("Mean Absolute Error:", mae)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 11.8858 - mae: 2.2661
# Test Loss: 11.885815620422363
# Mean Absolute Error: 2.2660505771636963

# %%
from sklearn.metrics import mean_squared_error
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print("MSE:", mse)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# MSE: 11.885815988426364

# %% [markdown]
# ## Visualization: Loss vs Epochs

# %%
plt.plot(history.history['loss'])
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Loss vs Epochs")
plt.show()

# %% [markdown]
# ## Visualization: Training vs Validation Loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(['Training Loss','Validation Loss'])
plt.title("Training vs Validation Loss")
plt.show()

# %% [markdown]
# ## Conclusion
#
# A Neural Network model was successfully implemented for regression. The model learned complex relationships in the dataset and achieved reasonable prediction accuracy. Loss curves indicated effective training and convergence.

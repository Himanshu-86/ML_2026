# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu-86/ML_2026/blob/main/Movie_Recommendation_System_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Movie Recommendation System**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Load Dataset

# %%
df=pd.read_csv("/content/tmdb_5000_movies.csv")
data=pd.read_csv("/content/tmdb_5000_credits.csv")

# %%
df.sample(5)
# Out:
#          budget                                             genres  \
# 1347   36000000  [{"id": 28, "name": "Action"}, {"id": 18, "nam...
# 3870    3800000                      [{"id": 18, "name": "Drama"}]
# 405    85000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 2014   25000000  [{"id": 27, "name": "Horror"}, {"id": 53, "nam...
#
#                                               homepage      id  \
# 1347  http://www.newline.com/properties/manaparta.html    8409
# 3870                                               NaN  103663
# 405              http://www.thefastandthefurious3.com/    9615
# 4                 http://movies.disney.com/john-carter   49529
# 2014                     http://www.1408-themovie.com/    3021
#
#                                                keywords original_language  \
# 1347  [{"id": 1522, "name": "repayment"}, {"id": 167...                en
# ...

# %%
df.shape
# Out:
# (4803, 20)

# %%
data.sample(5)
# Out:
#       movie_id                              title  \
# 3703     65749                              Tango
# 4771    220490  Her Cry: La Llorona Investigation
# 629     136797                     Need for Speed
# 228      75612                           Oblivion
# 1527      2054                 Mr. Holland's Opus
#
#                                                    cast  \
# 3703  [{"cast_id": 2, "character": "Mario Su\u00e1re...
# 4771  [{"cast_id": 1, "character": "Tina", "credit_i...
# 629   [{"cast_id": 8, "character": "Tobey Marshall",...
# 228   [{"cast_id": 1, "character": "Jack Harper", "c...
# 1527  [{"cast_id": 10, "character": "Glenn Holland",...
#
#                                                    crew
# 3703  [{"credit_id": "58070fa29251415b900118c7", "de...
# 4771  [{"credit_id": "52fe4dab9251416c7513cb8f", "de...
# 629   [{"credit_id": "53c1c8f50e0a26158f0098bd", "de...
# 228   [{"credit_id": "52fe4909c3a368484e11767f", "de...
# ...

# %%
data.shape
# Out:
# (4803, 4)

# %% [markdown]
# Merge Datasets

# %%
movies = df.merge(data, on='title')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %% [markdown]
# Select Important Columns

# %%
# Select only required columns
movies = movies[['movie_id','title','overview','genres','keywords','cast','crew']]

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %% [markdown]
# Handle Missing Values

# %%
# check total null values
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    3
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
# Remove rows with missing values
movies.dropna(inplace=True)

# %% [markdown]
# Convert String List to Python List

# %%
# To convert string to list
import ast

# %%
# Function to extract genre names
def convert(text):
    L = []
    for i in ast.literal_eval(text):
        L.append(i['name'])
    return L

# %%
movies['genres'] = movies['genres'].apply(convert)
movies['keywords'] = movies['keywords'].apply(convert)

# %% [markdown]
# Extract Top Cast

# %%
# Function to get first 3 cast members
def convert_cast(text):
    L = []
    counter = 0
    for i in ast.literal_eval(text):
        if counter != 3:
            L.append(i['name'])
            counter += 1
        else:
            break
    return L

movies['cast'] = movies['cast'].apply(convert_cast)

# %% [markdown]
# Extract Director from Crew

# %%
# Function to get director name
def fetch_director(text):
    L = []
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
            L.append(i['name'])
    return L

movies['crew'] = movies['crew'].apply(fetch_director)

# %% [markdown]
# Convert Overview into List

# %%
# Convert overview sentence into list of words
movies['overview'] = movies['overview'].apply(lambda x:x.split())

# %% [markdown]
# Remove Spaces from Names

# %%
movies['genres'] = movies['genres'].apply(lambda x:[i.replace(" ","") for i in x])
movies['keywords'] = movies['keywords'].apply(lambda x:[i.replace(" ","") for i in x])
movies['cast'] = movies['cast'].apply(lambda x:[i.replace(" ","") for i in x])
movies['crew'] = movies['crew'].apply(lambda x:[i.replace(" ","") for i in x])

# %% [markdown]
# Create Tags Column

# %%
# Combine all important columns
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
movies
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4804      9367                               El Mariachi
# 4805     72766                                 Newlyweds
# 4806    231617                 Signed, Sealed, Delivered
# 4807    126186                          Shanghai Calling
# 4808     25975                         My Date with Drew
#
#                                                overview  \
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     [Captain, Barbossa,, long, believed, to, be, d...
# 2     [A, cryptic, message, from, Bond’s, past, send...
# ...

# %% [markdown]
# Create New DataFrame

# %%
# Create new dataframe
new_df = movies[['movie_id','title','tags']]

# %%
new_df
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4804      9367                               El Mariachi
# 4805     72766                                 Newlyweds
# 4806    231617                 Signed, Sealed, Delivered
# 4807    126186                          Shanghai Calling
# 4808     25975                         My Date with Drew
#
#                                                    tags
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     [Captain, Barbossa,, long, believed, to, be, d...
# 2     [A, cryptic, message, from, Bond’s, past, send...
# ...

# %% [markdown]
# Convert Tags to String

# %%
# Convert list into string
new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))
# Out:
# /tmp/ipykernel_2266/2139073130.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))

# %%
new_df
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4804      9367                               El Mariachi
# 4805     72766                                 Newlyweds
# 4806    231617                 Signed, Sealed, Delivered
# 4807    126186                          Shanghai Calling
# 4808     25975                         My Date with Drew
#
#                                                    tags
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# ...

# %% [markdown]
# Convert Text to Numerical Vectors

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Create CountVectorizer object
cv = CountVectorizer(max_features=5000, stop_words='english')

# Convert tags to vectors
vectors = cv.fit_transform(new_df['tags']).toarray()

# %% [markdown]
# Calculate Similarity:
# Cosine similarity measures how similar two movies are.

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Calculate cosine similarity between movies
similarity = cosine_similarity(vectors)

# %%
similarity
# Out:
# array([[1.        , 0.08858079, 0.05905386, ..., 0.02478408, 0.02599376,
#         0.        ],
#        [0.08858079, 1.        , 0.06451613, ..., 0.02707652, 0.        ,
#         0.        ],
#        [0.05905386, 0.06451613, 1.        , ..., 0.02707652, 0.        ,
#         0.        ],
#        ...,
#        [0.02478408, 0.02707652, 0.02707652, ..., 1.        , 0.07150969,
#         0.0489116 ],
#        [0.02599376, 0.        , 0.        , ..., 0.07150969, 1.        ,
#         0.05129892],
#        [0.        , 0.        , 0.        , ..., 0.0489116 , 0.05129892,
#         1.        ]])

# %% [markdown]
# Recommendation Function

# %%
# Function to recommend movies
def recommend(movie):

    # Get index of movie
    movie_index = new_df[new_df['title'] == movie].index[0]

    # Get similarity scores
    distances = similarity[movie_index]

    # Sort movies based on similarity score
    movie_list = sorted(list(enumerate(distances)), reverse=True, key=lambda x:x[1])[1:6]

    # Print recommended movies
    for i in movie_list:
        print(new_df.iloc[i[0]].title)

# %% [markdown]
# Test the Recommendation System

# %%
recommend("Spider-Man 2")
# Out:
# Spider-Man 3
# Spider-Man
# The Amazing Spider-Man 2
# The Amazing Spider-Man
# Hellboy II: The Golden Army
